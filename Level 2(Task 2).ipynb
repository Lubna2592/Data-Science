# %% [markdown]
# ## Task: Price Range Analysis
# Determine the most common price range among all the restaurants.
# Calculate the average rating for each price range.
# Identify the color that represents the highest average rating among different price ranges.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'your_dataset.csv' with the actual file path)
file_path = 'Dataset .csv'
df = pd.read_csv(file_path)

# %%
# Price Range Analysis
common_price_range = df['Price range'].mode().iloc[0]
common_price_range
# Out:
# 1

# %%
# Average Rating Calculation
avg_ratings = df.groupby('Price range')['Aggregate rating'].mean().reset_index()
avg_ratings
# Out:
#    Price range  Aggregate rating
# 0            1          1.999887
# 1            2          2.941054
# 2            3          3.683381
# 3            4          3.817918

# %%
# Identify Color for Highest Average Rating
max_avg_rating_price_range = avg_ratings.loc[avg_ratings['Aggregate rating'].idxmax()]['Price range']
color_for_highest_avg_rating = df[df['Price range'] == max_avg_rating_price_range]['Rating color'].iloc[0]
color_for_highest_avg_rating
# Out:
# 'Green'

# %%
# Visualization
plt.figure(figsize=(10, 6))
sns.barplot(x='Price range', y='Aggregate rating', data=avg_ratings, palette=color_map.values())
plt.title('Average Rating by Price Range')
plt.xlabel('Price Range')
plt.ylabel('Average Rating')
plt.show()
